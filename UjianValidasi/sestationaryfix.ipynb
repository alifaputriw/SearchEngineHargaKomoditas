# %%
from bs4 import BeautifulSoup
import requests
import urllib.request
import csv
from urllib.request import urlopen
from datetime import datetime
import time
import pandas as pd
import os
import math

with open ('F:\\SKRIPSI\\Topik2\\UjianValidasi\\LinkURL\\url_stationary.csv') as f:
    urls=(line.strip()for line in f)
    stat_list= []
    for row in urls:
        
        r = urlopen(row)
        soup = BeautifulSoup(r, "html.parser")
        try:
            page = soup.find('div',{'class':'pages'})
            page = page.find_all('li')
            total_page= len(page)
            print(total_page)
        except:
            total_page ='0'
           
        if total_page == '0':
            print(row)
            all_product= soup.find_all('li',{'class':'item last'})
            for item in all_product:
                try:
                    linkEcommerce = row
                except :
                    linkEcommerce = ''
                try:
                    link= item.find('a',{'class':'product-image'})
                    linkProduk= link.get('href')
                except:
                    linkProduk=''
                try:
                    name= item.find('a',{'class':'product-image'})
                    namaProduk= name.get('title')
                except:
                    namaProduk=''
                try:
                    harga_lama= item.find('p',{'class':'old-price'})
                    harga_lama= harga_lama.find_all('span',{'class':'price'})[0].text
                    harga_lama= harga_lama.replace('/n','')
                    hargaLama= harga_lama.replace(' ','')
                except:
                    harga_lama= item.find('div',{'class':'price-box'})
                    hargaLama= harga_lama.find_all('span',{'class':'price'})[0].text
                try:
                    harga_baru= item.find('p',{'class':'special-price'})
                    harga_baru= harga_baru.find_all('span',{'class':'price'})[0].text
                    harga_baru= harga_baru.replace('/n','')
                    hargaBaru= harga_baru.replace(' ','')
                except:
                    harga_baru= item.find('div',{'class':'price-box'})
                    hargaBaru= harga_baru.find_all('span',{'class':'price'})[0].text
                
                try:
                    u= urlopen(linkProduk)
                    umum= BeautifulSoup(u,'html.parser')
                    idProduk= umum.find_all('p',{'class':'sku'})[0].text
                except:
                    idProduk=''
                try:
                    u= urlopen(linkProduk)
                    umum= BeautifulSoup(u,'html.parser')
                    ketersediaanProduk= umum.find_all('p',{'class':'availability'})[0].text
                except:
                    ketersediaanProduk=''
                
                stationary=[linkEcommerce,linkProduk,idProduk, namaProduk ,hargaLama , hargaBaru,ketersediaanProduk, datetime.now().strftime("%y-%m-%d %H:%M")]
                stat_list.append(stationary)
        else:
            for i in range(total_page-1):
                
                change_url= row.replace(row, row+'?p=%s'%(i+1))
                print(change_url)
                c= urlopen(change_url)
                next_soup = BeautifulSoup(c, "html.parser")
                all_product= next_soup.find_all('li',{'class':'item last'})
                for item in all_product:
                    try:
                        linkEcommerce = row
                    except :
                        linkEcommerce = ''
                    try:
                        link= item.find('a',{'class':'product-image'})
                        linkProduk= link.get('href')
                    except:
                        linkProduk=''
                    try:
                        name= item.find('a',{'class':'product-image'})
                        namaProduk= name.get('title')
                    except:
                        namaProduk=''
                    try:
                        harga_lama= item.find('p',{'class':'old-price'})
                        harga_lama= harga_lama.find_all('span',{'class':'price'})[0].text
                        harga_lama= harga_lama.replace('/n','')
                        hargaLama= harga_lama.replace(' ','')
                    except:
                        harga_lama= item.find('div',{'class':'price-box'})
                        hargaLama= harga_lama.find_all('span',{'class':'price'})[0].text
                    try:
                        harga_baru= item.find('p',{'class':'special-price'})
                        harga_baru= harga_baru.find_all('span',{'class':'price'})[0].text
                        harga_baru= harga_baru.replace('/n','')
                        hargaBaru= harga_baru.replace(' ','')
                    except:
                        harga_baru= item.find('div',{'class':'price-box'})
                        hargaBaru= harga_baru.find_all('span',{'class':'price'})[0].text

                    try:
                        u= urlopen(linkProduk)
                        umum= BeautifulSoup(u,'html.parser')
                        idProduk= umum.find_all('p',{'class':'sku'})[0].text
                    except:
                        idProduk=''
                    try:
                        u= urlopen(linkProduk)
                        umum= BeautifulSoup(u,'html.parser')
                        ketersediaanProduk= umum.find_all('p',{'class':'availability'})[0].text
                    except:
                        ketersediaanProduk=''

                    stationary=[linkEcommerce,linkProduk,idProduk, namaProduk ,hargaLama , hargaBaru,ketersediaanProduk, datetime.now().strftime("%y-%m-%d %H:%M")]
                    stat_list.append(stationary)
                
    path = 'F:\\SKRIPSI\\Topik2\\UjianValidasi\\HasilScraper\\'#isifoldertujuan
    now = datetime.now()
    filename = 'stationary_%s_%s_%s %s_%s_%s_%s.csv'%(now.day,now.month,now.year,now.hour,now.minute,now.second,now.microsecond)
    df=pd.DataFrame(stat_list, columns=['linkEcommerce','linkProduk','idProduk', 'namaProduk' ,'hargaLama' , 'hargaBaru','ketersediaanProduk','tgl update'])
    df.to_csv(os.path.join(path, filename))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-fedf4cdcf527> in <module>()
#      15     for row in urls:
#      16
# ---> 17         r = urlopen(row)
#      18         soup = BeautifulSoup(r, "html.parser")
#      19         try:
#
# C:\Anaconda\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# C:\Anaconda\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     530         for processor in self.process_response.get(protocol, []):
#     531             meth = getattr(processor, meth_name)
# --> 532             response = meth(req, response)
#     533
#     534         return response
#
# ...
